# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# what is correaltion?
#
# A correlation is a ststistical measure of the realtionship between two varibles(x,y)
#
# the correlation coefficient is value from -1 to 1 ex:- -1,0,1

# %%
globalwarming_df = pd.read_csv("E:\Data set\Heatmap\Who_is_responsible_for_global_warming.csv")

# %%
globalwarming_df
# Out:
#           Country Name Country Code                          Indicator Name  \
# 0        United States          USA  CO2 emissions (metric tons per capita)
# 1       United Kingdom          GBR  CO2 emissions (metric tons per capita)
# 2                India          IND  CO2 emissions (metric tons per capita)
# 3                China          CHN  CO2 emissions (metric tons per capita)
# 4   Russian Federation          RUS  CO2 emissions (metric tons per capita)
# 5            Australia          AUS  CO2 emissions (metric tons per capita)
# 6               France          FRA  CO2 emissions (metric tons per capita)
# 7              Germany          DEU  CO2 emissions (metric tons per capita)
# 8               Canada          CAN  CO2 emissions (metric tons per capita)
# 9               Brazil          BRA  CO2 emissions (metric tons per capita)
# 10           Argentina          ARG  CO2 emissions (metric tons per capita)
# 11            Pakistan          PAK  CO2 emissions (metric tons per capita)
# 12               Nepal          NPL  CO2 emissions (metric tons per capita)
# 13          Bangladesh          BGD  CO2 emissions (metric tons per capita)
# 14               Japan          JPN  CO2 emissions (metric tons per capita)
#
#     Indicator Code       2000       2001       2002       2003       2004  \
# 0   EN.ATM.CO2E.PC  20.178751  19.636505  19.613404  19.564105  19.658371
# 1   EN.ATM.CO2E.PC   9.199549   9.233175   8.904123   9.053278   8.989140
# 2   EN.ATM.CO2E.PC   0.979870   0.971698   0.967381   0.992392   1.025028
# 3   EN.ATM.CO2E.PC   2.696862   2.742121   3.007083   3.524074   4.037991
# 4   EN.ATM.CO2E.PC  10.627121  10.669603  10.715901  11.090647  11.120627
# 5   EN.ATM.CO2E.PC  17.200610  16.733367  17.370452  16.901959  17.026515
# 6   EN.ATM.CO2E.PC   5.946665   6.153061   6.068664   6.115998   6.120079
# 7   EN.ATM.CO2E.PC  10.095640  10.366287  10.058673   9.969355   9.898682
# 8   EN.ATM.CO2E.PC  17.367115  16.985030  16.559378  17.461199  17.258911
# 9   EN.ATM.CO2E.PC   1.871118   1.898354   1.844380   1.762482   1.828672
# 10  EN.ATM.CO2E.PC   3.835574   3.568600   3.291548   3.525584   4.069058
# 11  EN.ATM.CO2E.PC   0.768458   0.764702   0.788668   0.804959   0.872802
# 12  EN.ATM.CO2E.PC   0.129282   0.135226   0.106877   0.113902   0.105477
# 13  EN.ATM.CO2E.PC   0.211802   0.242020   0.246756   0.256602   0.266823
# 14  EN.ATM.CO2E.PC   9.622352   9.464309   9.573130   9.725282   9.909203
#
#          2005       2006       2007       2008       2009       2010  \
# 0   19.591885  19.094067  19.217898  18.461764  17.157738  17.442862
# 1    8.982939   8.898710   8.617164   8.424424   7.574622   7.857836
# 2    1.068563   1.121982   1.193210   1.310098   1.431844   1.397009
# 3    4.523178   4.980314   5.334910   5.701915   6.010102   6.560520
# 4   11.253529  11.669122  11.672457  12.014507  11.023856  11.694348
# 5   17.169711  17.651398  17.865260  18.160876  18.200182  17.740845
# 6    6.099599   5.906266   5.766385   5.690501   5.438357   5.428981
# 7    9.666372   9.911476   9.488040   9.506321   8.818596   9.279634
# 8   17.251083  16.696694  16.855883  16.875198  15.961560  15.723167
# 9    1.858088   1.839394   1.901372   2.008670   1.883812   2.132938
# 14   9.698883   9.632049   9.782964   9.449534   8.620816   9.148316
#
#          2011       2012       2013       2014
# 0   16.976957  16.310471  16.323477  16.502837
# 1    7.079298   7.355898   7.145844   6.497440
# 2    1.476686   1.598099   1.591438   1.730000
# 3    7.241515   7.424751   7.557211   7.543908
# 4   12.334881  12.784979  12.393556  11.857528
# 5   17.538878  17.072905  16.095833  15.388766
# 6    5.077911   5.075064   5.062174   4.573182
# 7    9.124859   9.199300   9.390623   8.889370
# 8   15.639760  14.890636  14.711972  15.117159
# 9    2.211587   2.343570   2.488417   2.594388
# 10   4.600291   4.569384   4.462904   4.746797
# 11   0.929801   0.918978   0.904316   0.896264
# 12   0.202491   0.211798   0.237170   0.283539
# 13   0.412011   0.433488   0.442401   0.459142
# 14   9.317427   9.638628   9.780815   9.538706

# %%
globalwarming_df = globalwarming_df.drop(columns = ['Country Code', 'Indicator Name', 'Indicator Code'],axis = 1).set_index('Country Name')
globalwarming_df.head(5)
# Out:
#                          2000       2001       2002       2003       2004  \
# Country Name
# United States       20.178751  19.636505  19.613404  19.564105  19.658371
# United Kingdom       9.199549   9.233175   8.904123   9.053278   8.989140
# India                0.979870   0.971698   0.967381   0.992392   1.025028
# China                2.696862   2.742121   3.007083   3.524074   4.037991
# Russian Federation  10.627121  10.669603  10.715901  11.090647  11.120627
#
#                          2005       2006       2007       2008       2009  \
# Country Name
# United States       19.591885  19.094067  19.217898  18.461764  17.157738
# United Kingdom       8.982939   8.898710   8.617164   8.424424   7.574622
# India                1.068563   1.121982   1.193210   1.310098   1.431844
# China                4.523178   4.980314   5.334910   5.701915   6.010102
# Russian Federation  11.253529  11.669122  11.672457  12.014507  11.023856
#
#                          2010       2011       2012       2013       2014
# Country Name
# United States       17.442862  16.976957  16.310471  16.323477  16.502837
# United Kingdom       7.857836   7.079298   7.355898   7.145844   6.497440
# India                1.397009   1.476686   1.598099   1.591438   1.730000
# China                6.560520   7.241515   7.424751   7.557211   7.543908
# Russian Federation  11.694348  12.334881  12.784979  12.393556  11.857528

# %%
sns.heatmap(globalwarming_df)
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
sns.heatmap(globalwarming_df)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# set value of color bar

plt.figure(figsize = (16,9))
sns.heatmap(globalwarming_df, vmin = 0, vmax = 21)
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
sns.heatmap(globalwarming_df, cmap = 'coolwarm')
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
sns.heatmap(globalwarming_df, cmap = 'coolwarm', annot = True)
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
annot_kws = { 'fontsize' : 10,
              'fontstyle': 'italic',
              'color' : 'k',
              'alpha' : 0.6,
              'rotation': 'vertical',
              'verticalalignment' : 'center',
              'backgroundcolor':'w'}

sns.heatmap(globalwarming_df, cmap = 'coolwarm', annot = True, annot_kws = annot_kws)
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
sns.heatmap(globalwarming_df, cmap = 'coolwarm', annot = True, linewidth = 4, linecolor = 'k')
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
sns.heatmap(globalwarming_df, cbar = False)
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
sns.heatmap(globalwarming_df, cbar = False, xticklabels = False)
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
sns.heatmap(globalwarming_df, cbar = False, xticklabels = False, yticklabels = False )
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
cbar_kws = { 'orientation': 'horizontal',
              'shrink' : 1,
              'extend' : 'min',
              'extendfrac' : 0.1,
              'ticks': np.arange(0,22),
              'drawedges' : True}

sns.heatmap(globalwarming_df, cbar_kws = cbar_kws)
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize = (16,9))
ax = sns.heatmap(globalwarming_df)
ax.set(title = "Heatmap of 'Whos is responsible for global warming'",
       xlabel = "Co2 emmisions (metric tons per capita) per year",
       ylabel = 'Country Name'
      )
sns.set(font_scale = 2)
